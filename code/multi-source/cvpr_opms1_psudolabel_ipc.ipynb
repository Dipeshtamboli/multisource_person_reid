# %%
import tensorflow as tf
import numpy as np
import scipy.io as sio
import sklearn as sk
import time
import random as rand
from random import randrange
#from numpy import array
#from numpy.linalg import norm
from flip_gradient import flip_gradient
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import csgraph
import os
import matplotlib.pyplot as plt
from random import *
from keras.layers import Dropout
from sklearn.metrics import recall_score

# %%
def splitarr(slist, k, index):
    p=index[0]
    st1=np.asarray(slist[p])
    for i in range(k-1):
        
        q=index[i+1]
        
        st2=np.asarray(slist[q])
        
        ar=np.vstack((st1, st2))
        
        st1=ar
        
    return ar

# %%
def aTolistC(array, class_l, n_classes):
    
    slist=[]
    l_list=[]
    
    for j in range(n_classes):
        k=[i for i,x in enumerate(class_l) if x == j]
        
        slist.append(array[k,:])
        l_list.append(class_l[k])
        
    return slist, l_list

# %%
def BatchGen_p(batch_size, source1, label1, source2, label2, source3, psudo, psudo_l):
    
    total_batch = 25
    
    src1=[]
    lab1=[]
    src2=[]
    lab2=[]
    src3=[]
    lab3=[]
    
    
    la_m2=tf.argmax(label2, 1)
    with tf.Session() as sess:
        la_m2=sess.run(la_m2)
    
    for i in range(total_batch):
        uidx=[]
        idx1 = rand.sample(range(1, source1.shape[0]), batch_size)
        src1.append(source1[idx1,:])
        lab1.append(label1[idx1,:])
        lab=label1[idx1,:]
        la_m=tf.argmax(label1[idx1,:], 1)
        with tf.Session() as sess:
            la_m=sess.run(la_m)
        for j in range(batch_size):
            p=la_m[j]
            #print(p)
            result = [index for index, word in enumerate(la_m2) if word == p]
            q=randint(0, len(result)-1)
            #print(result[q])
            uidx.append(result[q])
            
        src2.append(source2[uidx,:])
        lab2.append(label2[uidx,:])
        
  
        
        idx3 = rand.sample(range(1, source3.shape[0]), batch_size)
        src3.append(source3[idx3,:])
        
    
    psudo_renge = int(psudo.shape[0]/batch_size)
    
    #print("kkkkkkkkkkkkkkkkkkkkkkkkkkk")
    #print(psudo)
    #print("hhhhhhhhhhhhhhhhhhhhhhhhhhhh")
    #print(psudo[0])
    #print("lllllllllllllllllllllllll")
    
    #print(psudo[0:5])
    
    start = 0
    for i in range(psudo_renge):
        psu = psudo[start:start+batch_size]
        psu_l = psudo_l[start:start+batch_size]
        
        src1.append(psu)
        lab1.append(psu_l)
        
        src2.append(psu)
        
        lab2.append(psu_l)
        
        src3.append(psu)
        
        start = start+batch_size
    total_batch_after_p = len(src1)
        
    
    
        
    
    
       
    return total_batch_after_p, src1,lab1,src2,lab2, src3

# %%
def BatchGen(batch_size, source1, label1, source2, label2, source3):
    
    total_batch = 25
    
    src1=[]
    lab1=[]
    src2=[]
    lab2=[]
    src3=[]
    lab3=[]
    
    
    la_m2=tf.argmax(label2, 1)
    with tf.Session() as sess:
        la_m2=sess.run(la_m2)
    
    for i in range(total_batch):
        uidx=[]
        idx1 = rand.sample(range(1, source1.shape[0]), batch_size)
        src1.append(source1[idx1,:])
        lab1.append(label1[idx1,:])
        lab=label1[idx1,:]
        la_m=tf.argmax(label1[idx1,:], 1)
        with tf.Session() as sess:
            la_m=sess.run(la_m)
        for j in range(batch_size):
            p=la_m[j]
            #print(p)
            result = [index for index, word in enumerate(la_m2) if word == p]
            q=randint(0, len(result)-1)
            #print(result[q])
            uidx.append(result[q])
            
        src2.append(source2[uidx,:])
        lab2.append(label2[uidx,:])
    
        idx3 = rand.sample(range(1, source3.shape[0]), batch_size)
        src3.append(source3[idx3,:])
       
    return src1,lab1,src2,lab2, src3

# %%
# importing csv module 
import csv 


def csvToarr(filename):
    
    # initializing the titles and rows list 
    fields = [] 
    rows = [] 
  
    # reading csv file 
    with open(filename, 'r') as csvfile: 
        # creating a csv reader object 
        csvreader = csv.reader(csvfile) 
      
        # extracting field names through first row 
        fields = next(csvreader) 
  
        # extracting each data row one by one 
        for row in csvreader: 
            rows.append(row) 
  
        # get total number of rows 
    print("Total no. of rows: %d"%(csvreader.line_num))
        
    return np.asarray(rows)

# %%
# csv file name 
amazon = 'c_c.csv'
digitalSlr = 'i_i.csv'
webcam = 'p_p.csv'

# %%
ama_=csvToarr(amazon)
dslr_=csvToarr(digitalSlr)
web_=csvToarr(webcam)
# Out:
# Total no. of rows: 600
# Total no. of rows: 600
# Total no. of rows: 600

# %%
ama_l=ama_[:,-1]
ama=ama_[:,0:ama_.shape[1] -1]

dslr_l=dslr_[:,-1]
dslr=dslr_[:,0:dslr_.shape[1] -1]

web_l=web_[:,-1]
web=web_[:,0:web_.shape[1]-1]

# %%
n_class = len(np.unique(ama_l))
print(n_class)
# Out:
# 12

# %%
ama=ama.astype(np.float32)
ama_l=ama_l.astype(np.float32)

dslr=dslr.astype(np.float32)
dslr_l=dslr_l.astype(np.float32)

web=web.astype(np.float32)
web_l=web_l.astype(np.float32)

# %%
ama_ll=ama_l.reshape(ama_l.shape[0], 1)

dslr_ll=dslr_l.reshape(dslr_l.shape[0], 1)

web_ll=web_l.reshape(web_l.shape[0], 1)

# %%
amaS, amaL=aTolistC(ama, ama_ll, n_class)

# %%
dslrS, dslrL=aTolistC(dslr, dslr_ll, n_class)

# %%
webS, webL=aTolistC(web, web_ll, n_class)

# %%
s1_l=[0,1,2,3,4,5,6,7]
s2_l=[0,1,2,3,4,5,6,7]

# %%
s11=  dslrS # ii
s11_l=  dslrL

T1=  webS # pp
T1_l= webL

s22= amaS # cc
s22_l= amaL

# %%
##### (source1)
sou1= splitarr(s11, 8, s1_l)
sou1_l=splitarr(s11_l, 8, s1_l)

# %%
print(len(np.unique(sou1_l)))
# Out:
# 8

# %%
##### (source2)
sou2= splitarr(s22, 8, s2_l)
sou2_l=splitarr(s22_l, 8, s2_l)
#print(sou2_l)

# %%
sou2_l = sou2_l.ravel()
sou1_l = sou1_l.ravel()

# %%
tar = web
tar_ll = web_ll

# %%
tar_llk = np.copy(tar_ll)

# %%
# Target Label update
r=tar_ll.shape[0]
for i in range (r):
    
    if tar_ll[i] >= 8:
        
        tar_llk[i] = 8

# %%
n_classes = len(np.unique(tar_llk))
print(n_classes)
tar_llk = tar_llk.ravel()
#web_llk
# Out:
# 9

# %%
tar_l = tar_llk

# %%
sou1_l_h=tf.one_hot(sou1_l, n_classes)
sou2_l_h=tf.one_hot(sou2_l, n_classes)
tar_l_h=tf.one_hot(tar_l, n_classes)
with tf.Session() as sess:
    sou1_l_h=sess.run(sou1_l_h)
    sou2_l_h=sess.run(sou2_l_h)
    tar_l_h=sess.run(tar_l_h)
#print(tar_l_h[0])

# %%
#a,b,c,d,e,g = BatchGen(10, sou1,sou1_l_h, sou2, sou2_l_h, web, tar_l_h )

# %%
def weight_variable(shape):
    
    
    initial = tf.random_normal(shape, stddev=0.1)
    #initial = tf.truncated_normal(shape)#, stddev=0.1)
    return tf.Variable(initial)

def bise_variable(shape):
   
    initial = tf.random_normal(shape)
    #initial = tf.constant(0.1, "float32", shape)
    return tf.Variable(initial)

# %%
n_features=sou1.shape[1]

X1= tf.placeholder(tf.float32, [None, n_features], name='X1' ) # Source1 Input data 
Y1_ind = tf.placeholder(tf.float32, [None, n_classes], name= 'Y1_ind')  # Source1 label index 

X2= tf.placeholder(tf.float32, [None, n_features], name='X2' ) # Source2 Input data 
Y2_ind = tf.placeholder(tf.float32, [None, n_classes], name= 'Y2_ind')  # Source2 label index 

X3= tf.placeholder(tf.float32, [None, n_features], name='X3' ) # Target Input data 
Y3_ind = tf.placeholder(tf.float32, [None, n_classes], name= 'Y2_ind')  # Source3 label index 
l = tf.placeholder(tf.float32, [], name= 'l')  # gradient reversal layer

# %%
num_inputs=n_features    
num_hid1=1000
num_hid2=500
num_hid3=128

# %%
w1_1=tf.Variable(tf.random_normal([num_inputs, num_hid1], stddev = 0.01), name= 'w1_1')
b1_1=tf.Variable(tf.random_normal([num_hid1]), name = 'b1_1')

w1_2=tf.Variable(tf.random_normal([num_inputs, num_hid1], stddev = 0.01), name= 'w1_2')
b1_2=tf.Variable(tf.random_normal([num_hid1]), name = 'b1_2')

w2_1=tf.Variable(tf.random_normal([num_hid1, num_hid2], stddev = 0.01), name= 'w2_1')
b2_1=tf.Variable(tf.random_normal([num_hid2]), name = 'b2_1')

w2_2=tf.Variable(tf.random_normal([num_hid1, num_hid2]), name= 'w2_2')
b2_2=tf.Variable(tf.random_normal([num_hid2]), name = 'b2_2')

# %%
w5_1=tf.Variable(tf.random_normal([num_hid2, num_hid3], stddev = 0.01), name= 'w5_1')
b5_1=tf.Variable(tf.random_normal([num_hid3]), name = 'b5_1')

w6_1=tf.Variable(tf.random_normal([num_hid3, n_classes], stddev = 0.01), name= 'w6_1')
b6_1=tf.Variable(tf.random_normal([n_classes]), name = 'b6_1')



w5_2=tf.Variable(tf.random_normal([num_hid2, num_hid3], stddev = 0.01), name= 'w5_2')
b5_2=tf.Variable(tf.random_normal([num_hid3]), name = 'b5_2')

w6_2=tf.Variable(tf.random_normal([num_hid3, n_classes], stddev = 0.01), name= 'w6_2')
b6_2=tf.Variable(tf.random_normal([n_classes]), name = 'b6_2')

# %%
def generator(z1, z2, z3):
    
    #with tf.variable_scope("FeatureGenerator",reuse=True):
        
    sh1_1=tf.layers.batch_normalization(tf.nn.relu(tf.matmul(z1, w1_1) + b1_1))   # source1
    #sh1_1 = Dropout(0.3)(sh1_1, training=True)
    sh2_1=tf.layers.batch_normalization(tf.nn.relu(tf.matmul(z2, w1_1) + b1_1))   # source2
    #sh2_1 = Dropout(0.3)(sh2_1, training=True)
    T1=tf.nn.relu(tf.matmul(z3, w1_1) + b1_1)    # Target
        
    sh1_2=tf.layers.batch_normalization(tf.nn.relu(tf.matmul(sh1_1, w2_1) + b2_1))   # source1
    #sh1_2 = Dropout(0.3)(sh1_2, training=True)
    sh2_2=tf.layers.batch_normalization(tf.nn.relu(tf.matmul(sh2_1, w2_1) + b2_1))   # source2
    #sh2_2 = Dropout(0.3)(sh2_2, training=True)
    T2=tf.nn.relu(tf.matmul(T1, w2_1) + b2_1)    # Target
        
    return sh1_2, sh2_2, T2

    
    
def classifier(x1, x2, t):
    
    #with tf.variable_scope("ClassClassifier", reuse = True ):
        
    X11 = tf.layers.batch_normalization(tf.nn.relu(tf.matmul(x1, w5_1) + b5_1))   # 1st layer for source1
    t11 = tf.layers.batch_normalization(tf.nn.relu(tf.matmul(t, w5_1) + b5_1))   # 1st layer target through source1
    
    p_logit_X1 = tf.matmul(X11, w6_1) + b6_1   # logit for source1
    p_logit_t1 = tf.matmul(t11, w6_1) + b6_1   # logit for target through source1
       
        
    X22 = tf.layers.batch_normalization(tf.nn.relu(tf.matmul(x2, w5_2) + b5_2))     # 2nd layer for source2
    t22 = tf.layers.batch_normalization(tf.nn.relu(tf.matmul(t, w5_2) + b5_2))   # 2nd layer target through source2
    
    p_logit_X2 = tf.matmul(X22, w6_2) + b6_2   # logit for source1
    p_logit_t2 = tf.matmul(t22, w6_2) + b6_2   # logit for target through source1
        
    p_logit_t = (p_logit_t1 + p_logit_t2)/2
        
    p_X1 = tf.nn.softmax(p_logit_X1)
        
    p_X2 = tf.nn.softmax(p_logit_X2)
        
    p_t = tf.nn.softmax(p_logit_t)
    
    p_t1 = tf.argmax(p_t,1)
        
        
    return p_logit_X1, p_logit_X2, p_logit_t, p_X1, p_X2, p_t, p_t1

# %%
s1_f, s2_f, t_f = generator(X1, X2, X3)

logit_x1, logit_x2, logit_t, px1, px2, p_t, p_t1 = classifier(s1_f, s2_f, t_f)

t = 0.5

# %%
p_loss_X1 = tf.nn.softmax_cross_entropy_with_logits(logits = logit_x1, labels = Y1_ind)
p_loss_X2 = tf.nn.softmax_cross_entropy_with_logits(logits = logit_x2, labels = Y2_ind)

p_loss_s1_s2 = tf.reduce_mean(tf.pow(s1_f - s2_f ,2), 1)



loss_cl = tf.reduce_mean(p_loss_X1) + tf.reduce_mean(p_loss_X2)

loss1 = loss_cl + p_loss_s1_s2

p_kone=tf.gather(p_t,indices=[n_classes-1],axis=1)
Ladv=-0.5*tf.reduce_mean(tf.log(p_kone+1e-8))-0.5*tf.reduce_mean((tf.log(1.0-(p_kone)+1e-8)))

jh= p_t[:, :n_classes-1]

kh=tf.argmax(jh, axis = 1)

pu_l_h=tf.one_hot(kh, n_classes)

gbp=p_t[:, -1]
hg = tf.reduce_mean(jh, 1)
alpha = 0.2
hing=tf.abs(p_t[:, -1] - hg) - alpha

row = jh.shape[0]
gg=0.0

bb=[]

for i in range(20):
    
    hgbw = tf.cond(hing[i]<gg, lambda: hing[i], lambda:gg)
    
    bb.append(hgbw)

hingh_loss=tf.reduce_mean(tf.stack(bb))  # hingh loss

loss2 = loss1 + Ladv  # classifier

loss3 = loss1 - Ladv - hingh_loss    # Generator

# %%
G_v = [w1_1, w2_1, b1_1, b2_1]
C_v = [w5_1, w5_2, b5_1, b5_2, w6_1, w6_2, b6_1, b6_2]

# %%
#loss_cl_op = tf.train.AdamOptimizer(0.001).minimize(loss1)

loss1C_op = tf.train.AdamOptimizer(0.001).minimize(loss2, var_list = C_v)

loss2G_op = tf.train.AdamOptimizer(0.001).minimize(loss3, var_list = G_v)

# %%
p1_acc =tf.reduce_mean(tf.cast(tf.equal(tf.argmax(Y1_ind, 1), tf.argmax(px1, 1)), tf.float32))

p2_acc =tf.reduce_mean(tf.cast(tf.equal(tf.argmax(Y2_ind, 1), tf.argmax(px2, 1)), tf.float32))

pt_all =tf.reduce_mean(tf.cast(tf.equal(tf.argmax(Y3_ind, 1), tf.argmax(p_t, 1)), tf.float32))

# %%
init=tf.global_variables_initializer()

# %%
num_epoch=100
batch_size=20
dp1 = 0.0
dp2 = 0.0
dp11 = 0.0
dp12 = 0.0

#ps_t = []
#ps_t_l = []

flag = 0

l1 = [0,1,2,3,4,5,6,7]
l2 = [0,1,2,3,4,5,6,7,8]

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(num_epoch):
        
        ps_t = []
        ps_t_l = []
        
        if flag ==0:
            total_batches = 25
            
            X1_batch,y1_batch, X2_batch,y2_batch, X3_batch=BatchGen(batch_size, sou1, sou1_l_h, sou2, sou2_l_h, tar)
        else:
            total_batches, X1_batch,y1_batch, X2_batch,y2_batch, X3_batch=BatchGen_p(batch_size, sou1, sou1_l_h, sou2,sou2_l_h, tar, psudo, psudo_l)
        
        flag = 0

        for batch in range(total_batches):
            
            xx_1=X1_batch[batch]
            #print(xx_1.shape)
            
            xx_2=X2_batch[batch]
            #print(xx_2.shape)
            
            xx_3=X3_batch[batch]
            #print(xx_3.shape)
            
            yy_1=y1_batch[batch]
            yy_2=y2_batch[batch]
            

            
            #_,batch_loss_cl  = sess.run([loss_cl_op, loss1],
                                        #feed_dict={X1: xx_1, X2:xx_2, Y1_ind:yy_1, Y2_ind:yy_2, X3:xx_3})
            
            _,batch_loss1C, pu_one_hot, pu_logit, pu_argmax  = sess.run([loss1C_op, loss2, pu_l_h, jh, kh],
                                        feed_dict={X1: xx_1, X2:xx_2, Y1_ind:yy_1, Y2_ind:yy_2, X3:xx_3})
            
            
            rr=0
            #print(mm)
            for v in range(pu_one_hot.shape[0]):
                
                ff = pu_one_hot[v]
                aa=pu_argmax[v]
                #dwq = tf.cast(ff, tf.int32)
               
                if pu_logit[rr, aa] >= 0.9:
                    flag = 1
                        
                    ps_t.append(xx_3[v, :])
                    ps_t_l.append(ff)
                    
    
                rr=rr+1
                    
            
            
            _,batch_loss2G  = sess.run([loss2G_op, loss3],
                                        feed_dict={X1: xx_1, X2:xx_2, Y1_ind:yy_1, Y2_ind:yy_2, X3:xx_3})
            
        #ps_t.append(xx_1)
        #ps_t_l.append(yy_1)
        psudo=np.asarray(ps_t)
        psudo_l = np.asarray(ps_t_l)
        
        
        print(len(ps_t))
        p = epoch%1
        
        if p==0:
            print("epoch#####555555555555##########################", epoch)
                    
            pas11 = sess.run([p1_acc], feed_dict={X1:tar, Y1_ind:tar_l_h})
            pas12 = sess.run([p2_acc], feed_dict={X2:tar, Y2_ind:tar_l_h})
            lab = sess.run([p_t1], feed_dict={X3:tar, Y3_ind:tar_l_h})
            pass_avg2 = sess.run([pt_all], feed_dict={X3:tar, Y3_ind:tar_l_h})

            lab = np.matrix.transpose(np.asarray(lab))

            OS = recall_score(tar_l, lab, labels=l2, average='macro')
            OS_star = recall_score(tar_l, lab, labels=l1, average='macro')
            
            print('target from source1', pas11)
            print('target from source2', pas12)
            print('OS', OS)
            print('OS-star', OS_star)
            print('OS-all', pass_avg2)
        
        if OS >= dp11:
            
            dp11=OS
            dp12=OS_star
            dp13 = pass_avg2[0]
            dp1 = pas11[0]
            dp2 = pas12[0]
            ep11=epoch

      
        print('print highest source1: %f, epoch%f'%(dp1, ep11))
        print('print highest source2: %f, epoch%f'%(dp2, ep11))
        print('print highest OS: %f, epoch%f'%(dp11, ep11))
        print('print highest OS-star: %f, epoch%f'%(dp12, ep11))
        print('print highest ALL: %f, epoch%f'%(dp13, ep11))
                            
    print("Training Complete")
    
    sess.close()
# Out:
# 0
# ('epoch#####555555555555##########################', 0)
# ('target from source1', [0.21368948])
# ('target from source2', [0.30884808])
# ('OS', 0.21410430839002265)
# ('OS-star', 0.1858673469387755)
# ('OS-all', [0.27045074])
# print highest source1: 0.213689, epoch0.000000
# print highest source2: 0.308848, epoch0.000000
# print highest OS: 0.214104, epoch0.000000
# print highest OS-star: 0.185867, epoch0.000000
# print highest ALL: 0.270451, epoch0.000000
# 0
# ('epoch#####555555555555##########################', 1)
# ('target from source1', [0.38230383])
# ('target from source2', [0.49081802])
# ('OS', 0.548673469387755)
# ('OS-star', 0.5891326530612244)
# ('OS-all', [0.46744573])
# print highest source1: 0.382304, epoch1.000000
# print highest source2: 0.490818, epoch1.000000
# print highest OS: 0.548673, epoch1.000000
# print highest OS-star: 0.589133, epoch1.000000
# print highest ALL: 0.467446, epoch1.000000
# 12
# ('epoch#####555555555555##########################', 2)
# ('target from source1', [0.52587646])
# ('target from source2', [0.5843072])
# ('OS', 0.6313492063492063)
# ('OS-star', 0.6621428571428571)
# ('OS-all', [0.5692821])
# print highest source1: 0.525876, epoch2.000000
# print highest source2: 0.584307, epoch2.000000
# print highest OS: 0.631349, epoch2.000000
# print highest OS-star: 0.662143, epoch2.000000
# print highest ALL: 0.569282, epoch2.000000
# 65
# ('epoch#####555555555555##########################', 3)
# ('target from source1', [0.65776294])
# ('target from source2', [0.64440733])
# ('OS', 0.7153287981859411)
# ('OS-star', 0.7422448979591837)
# ('OS-all', [0.6611018])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 97
# ('epoch#####555555555555##########################', 4)
# ('target from source1', [0.66444075])
# ('target from source2', [0.6377295])
# ('OS', 0.6206122448979592)
# ('OS-star', 0.6019387755102041)
# ('OS-all', [0.65776294])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 144
# ('epoch#####555555555555##########################', 5)
# ('target from source1', [0.639399])
# ('target from source2', [0.639399])
# ('OS', 0.6594557823129252)
# ('OS-star', 0.6743877551020409)
# ('OS-all', [0.6293823])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 206
# ('epoch#####555555555555##########################', 6)
# ('target from source1', [0.55926543])
# ('target from source2', [0.5993322])
# ('OS', 0.6638095238095238)
# ('OS-star', 0.7042857142857143)
# ('OS-all', [0.5826377])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 185
# ('epoch#####555555555555##########################', 7)
# ('target from source1', [0.60601])
# ('target from source2', [0.6076795])
# ('OS', 0.6752380952380953)
# ('OS-star', 0.7021428571428572)
# ('OS-all', [0.62103504])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 205
# ('epoch#####555555555555##########################', 8)
# ('target from source1', [0.5642738])
# ('target from source2', [0.5008347])
# ('OS', 0.46255102040816326)
# ('OS-star', 0.4297448979591837)
# ('OS-all', [0.5275459])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 187
# ('epoch#####555555555555##########################', 9)
# ('target from source1', [0.5692821])
# ('target from source2', [0.6494157])
# ('OS', 0.7020408163265306)
# ('OS-star', 0.727295918367347)
# ('OS-all', [0.65108514])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 180
# ('epoch#####555555555555##########################', 10)
# ('target from source1', [0.6360601])
# ('target from source2', [0.64106846])
# ('OS', 0.6674149659863945)
# ('OS-star', 0.6670918367346939)
# ('OS-all', [0.6677796])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 216
# ('epoch#####555555555555##########################', 11)
# ('target from source1', [0.6377295])
# ('target from source2', [0.6627713])
# ('OS', 0.6709297052154195)
# ('OS-star', 0.674795918367347)
# ('OS-all', [0.6627713])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 169
# ('epoch#####555555555555##########################', 12)
# ('target from source1', [0.6594324])
# ('target from source2', [0.639399])
# ('OS', 0.6757482993197279)
# ('OS-star', 0.6820918367346939)
# ('OS-all', [0.6627713])
# print highest source1: 0.657763, epoch3.000000
# print highest source2: 0.644407, epoch3.000000
# print highest OS: 0.715329, epoch3.000000
# print highest OS-star: 0.742245, epoch3.000000
# print highest ALL: 0.661102, epoch3.000000
# 172
# ('epoch#####555555555555##########################', 13)
# ('target from source1', [0.64440733])
# ('target from source2', [0.6093489])
# ('OS', 0.7156575963718822)
# ('OS-star', 0.7494897959183674)
# ('OS-all', [0.64774626])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 143
# ('epoch#####555555555555##########################', 14)
# ('target from source1', [0.6560935])
# ('target from source2', [0.6611018])
# ('OS', 0.7096825396825397)
# ('OS-star', 0.7271428571428571)
# ('OS-all', [0.67445743])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 150
# ('epoch#####555555555555##########################', 15)
# ('target from source1', [0.654424])
# ('target from source2', [0.6594324])
# ('OS', 0.6924149659863945)
# ('OS-star', 0.7095918367346938)
# ('OS-all', [0.65776294])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 171
# ('epoch#####555555555555##########################', 16)
# ('target from source1', [0.6293823])
# ('target from source2', [0.6611018])
# ('OS', 0.681814058956916)
# ('OS-star', 0.6920408163265306)
# ('OS-all', [0.6611018])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 176
# ('epoch#####555555555555##########################', 17)
# ('target from source1', [0.63439065])
# ('target from source2', [0.6527546])
# ('OS', 0.6828344671201814)
# ('OS-star', 0.689438775510204)
# ('OS-all', [0.6694491])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 156
# ('epoch#####555555555555##########################', 18)
# ('target from source1', [0.64440733])
# ('target from source2', [0.64106846])
# ('OS', 0.6807936507936508)
# ('OS-star', 0.6821428571428572)
# ('OS-all', [0.6777963])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 135
# ('epoch#####555555555555##########################', 19)
# ('target from source1', [0.5993322])
# ('target from source2', [0.6677796])
# ('OS', 0.7113492063492064)
# ('OS-star', 0.7396428571428572)
# ('OS-all', [0.654424])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 141
# ('epoch#####555555555555##########################', 20)
# ('target from source1', [0.639399])
# ('target from source2', [0.64774626])
# ('OS', 0.666814058956916)
# ('OS-star', 0.6745408163265306)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 179
# ('epoch#####555555555555##########################', 21)
# ('target from source1', [0.6227045])
# ('target from source2', [0.6527546])
# ('OS', 0.6840816326530612)
# ('OS-star', 0.6995918367346938)
# ('OS-all', [0.6527546])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 153
# ('epoch#####555555555555##########################', 22)
# ('target from source1', [0.64774626])
# ('target from source2', [0.654424])
# ('OS', 0.6785260770975057)
# ('OS-star', 0.6870918367346939)
# ('OS-all', [0.6611018])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 156
# ('epoch#####555555555555##########################', 23)
# ('target from source1', [0.59599334])
# ('target from source2', [0.6527546])
# ('OS', 0.6929705215419502)
# ('OS-star', 0.7145918367346938)
# ('OS-all', [0.6494157])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 152
# ('epoch#####555555555555##########################', 24)
# ('target from source1', [0.6427379])
# ('target from source2', [0.6460768])
# ('OS', 0.6635260770975058)
# ('OS-star', 0.6595918367346939)
# ('OS-all', [0.67111856])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 149
# ('epoch#####555555555555##########################', 25)
# ('target from source1', [0.5826377])
# ('target from source2', [0.5993322])
# ('OS', 0.6402380952380953)
# ('OS-star', 0.6371428571428572)
# ('OS-all', [0.6460768])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 151
# ('epoch#####555555555555##########################', 26)
# ('target from source1', [0.60601])
# ('target from source2', [0.639399])
# ('OS', 0.6956575963718821)
# ('OS-star', 0.7219897959183673)
# ('OS-all', [0.6427379])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 145
# ('epoch#####555555555555##########################', 27)
# ('target from source1', [0.6360601])
# ('target from source2', [0.639399])
# ('OS', 0.6929705215419502)
# ('OS-star', 0.7120918367346939)
# ('OS-all', [0.654424])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 169
# ('epoch#####555555555555##########################', 28)
# ('target from source1', [0.6260434])
# ('target from source2', [0.6460768])
# ('OS', 0.6518594104308391)
# ('OS-star', 0.652091836734694)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 168
# ('epoch#####555555555555##########################', 29)
# ('target from source1', [0.6460768])
# ('target from source2', [0.6327212])
# ('OS', 0.6555668934240363)
# ('OS-star', 0.6568877551020408)
# ('OS-all', [0.6527546])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 163
# ('epoch#####555555555555##########################', 30)
# ('target from source1', [0.6293823])
# ('target from source2', [0.64774626])
# ('OS', 0.6646371882086167)
# ('OS-star', 0.6670918367346939)
# ('OS-all', [0.6594324])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 150
# ('epoch#####555555555555##########################', 31)
# ('target from source1', [0.6377295])
# ('target from source2', [0.654424])
# ('OS', 0.6740816326530612)
# ('OS-star', 0.6770918367346939)
# ('OS-all', [0.6677796])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 123
# ('epoch#####555555555555##########################', 32)
# ('target from source1', [0.66444075])
# ('target from source2', [0.639399])
# ('OS', 0.6901927437641722)
# ('OS-star', 0.7020918367346938)
# ('OS-all', [0.66611016])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 160
# ('epoch#####555555555555##########################', 33)
# ('target from source1', [0.590985])
# ('target from source2', [0.62771285])
# ('OS', 0.6617233560090703)
# ('OS-star', 0.6769387755102041)
# ('OS-all', [0.6310518])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 163
# ('epoch#####555555555555##########################', 34)
# ('target from source1', [0.61435723])
# ('target from source2', [0.65108514])
# ('OS', 0.6634353741496599)
# ('OS-star', 0.6594897959183673)
# ('OS-all', [0.67111856])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 149
# ('epoch#####555555555555##########################', 35)
# ('target from source1', [0.6010017])
# ('target from source2', [0.6310518])
# ('OS', 0.659829931972789)
# ('OS-star', 0.6591836734693877)
# ('OS-all', [0.6611018])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 152
# ('epoch#####555555555555##########################', 36)
# ('target from source1', [0.6126878])
# ('target from source2', [0.639399])
# ('OS', 0.6784353741496598)
# ('OS-star', 0.6844897959183673)
# ('OS-all', [0.66611016])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 142
# ('epoch#####555555555555##########################', 37)
# ('target from source1', [0.65108514])
# ('target from source2', [0.6310518])
# ('OS', 0.6601927437641724)
# ('OS-star', 0.6645918367346939)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 177
# ('epoch#####555555555555##########################', 38)
# ('target from source1', [0.55592656])
# ('target from source2', [0.6310518])
# ('OS', 0.6784353741496598)
# ('OS-star', 0.6919897959183673)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 156
# ('epoch#####555555555555##########################', 39)
# ('target from source1', [0.5175292])
# ('target from source2', [0.59599334])
# ('OS', 0.5724716553287981)
# ('OS-star', 0.5690306122448979)
# ('OS-all', [0.57929885])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 181
# ('epoch#####555555555555##########################', 40)
# ('target from source1', [0.5525876])
# ('target from source2', [0.6260434])
# ('OS', 0.663390022675737)
# ('OS-star', 0.664438775510204)
# ('OS-all', [0.6611018])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 150
# ('epoch#####555555555555##########################', 41)
# ('target from source1', [0.6560935])
# ('target from source2', [0.6293823])
# ('OS', 0.6756122448979593)
# ('OS-star', 0.6844387755102042)
# ('OS-all', [0.65776294])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 150
# ('epoch#####555555555555##########################', 42)
# ('target from source1', [0.58096826])
# ('target from source2', [0.6293823])
# ('OS', 0.6783446712018141)
# ('OS-star', 0.6868877551020408)
# ('OS-all', [0.6611018])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 148
# ('epoch#####555555555555##########################', 43)
# ('target from source1', [0.6076795])
# ('target from source2', [0.60601])
# ('OS', 0.6745011337868481)
# ('OS-star', 0.6819387755102041)
# ('OS-all', [0.6594324])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 158
# ('epoch#####555555555555##########################', 44)
# ('target from source1', [0.59599334])
# ('target from source2', [0.6377295])
# ('OS', 0.6827891156462585)
# ('OS-star', 0.6918877551020408)
# ('OS-all', [0.66444075])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 157
# ('epoch#####555555555555##########################', 45)
# ('target from source1', [0.58764607])
# ('target from source2', [0.6076795])
# ('OS', 0.6778344671201815)
# ('OS-star', 0.6869387755102041)
# ('OS-all', [0.6594324])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 146
# ('epoch#####555555555555##########################', 46)
# ('target from source1', [0.61936563])
# ('target from source2', [0.6076795])
# ('OS', 0.6684353741496598)
# ('OS-star', 0.6744897959183673)
# ('OS-all', [0.6560935])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 145
# ('epoch#####555555555555##########################', 47)
# ('target from source1', [0.57429045])
# ('target from source2', [0.60434055])
# ('OS', 0.6624149659863946)
# ('OS-star', 0.662091836734694)
# ('OS-all', [0.6627713])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 153
# ('epoch#####555555555555##########################', 48)
# ('target from source1', [0.6327212])
# ('target from source2', [0.6076795])
# ('OS', 0.6823696145124717)
# ('OS-star', 0.6920408163265306)
# ('OS-all', [0.6627713])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 146
# ('epoch#####555555555555##########################', 49)
# ('target from source1', [0.62771285])
# ('target from source2', [0.59766275])
# ('OS', 0.6750113378684808)
# ('OS-star', 0.6818877551020408)
# ('OS-all', [0.6611018])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 168
# ('epoch#####555555555555##########################', 50)
# ('target from source1', [0.63439065])
# ('target from source2', [0.5943239])
# ('OS', 0.6734353741496597)
# ('OS-star', 0.6869897959183673)
# ('OS-all', [0.6460768])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 170
# ('epoch#####555555555555##########################', 51)
# ('target from source1', [0.60601])
# ('target from source2', [0.57262105])
# ('OS', 0.6678798185941043)
# ('OS-star', 0.6694897959183673)
# ('OS-all', [0.66444075])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 162
# ('epoch#####555555555555##########################', 52)
# ('target from source1', [0.6360601])
# ('target from source2', [0.60434055])
# ('OS', 0.6667687074829932)
# ('OS-star', 0.6644897959183673)
# ('OS-all', [0.67111856])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 171
# ('epoch#####555555555555##########################', 53)
# ('target from source1', [0.60434055])
# ('target from source2', [0.59599334])
# ('OS', 0.6722789115646257)
# ('OS-star', 0.671938775510204)
# ('OS-all', [0.67278796])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 153
# ('epoch#####555555555555##########################', 54)
# ('target from source1', [0.624374])
# ('target from source2', [0.59766275])
# ('OS', 0.6594557823129251)
# ('OS-star', 0.6618877551020408)
# ('OS-all', [0.654424])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 139
# ('epoch#####555555555555##########################', 55)
# ('target from source1', [0.5609349])
# ('target from source2', [0.5926544])
# ('OS', 0.6584353741496599)
# ('OS-star', 0.6669897959183674)
# ('OS-all', [0.64106846])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 160
# ('epoch#####555555555555##########################', 56)
# ('target from source1', [0.5676127])
# ('target from source2', [0.6126878])
# ('OS', 0.6817687074829931)
# ('OS-star', 0.6919897959183673)
# ('OS-all', [0.6611018])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 150
# ('epoch#####555555555555##########################', 57)
# ('target from source1', [0.61435723])
# ('target from source2', [0.6093489])
# ('OS', 0.6624149659863945)
# ('OS-star', 0.6645918367346939)
# ('OS-all', [0.65776294])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 169
# ('epoch#####555555555555##########################', 58)
# ('target from source1', [0.54924875])
# ('target from source2', [0.61435723])
# ('OS', 0.6714965986394558)
# ('OS-star', 0.6816836734693877)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 159
# ('epoch#####555555555555##########################', 59)
# ('target from source1', [0.5676127])
# ('target from source2', [0.5709516])
# ('OS', 0.6562131519274377)
# ('OS-star', 0.6569897959183674)
# ('OS-all', [0.654424])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 158
# ('epoch#####555555555555##########################', 60)
# ('target from source1', [0.5525876])
# ('target from source2', [0.5776294])
# ('OS', 0.5682993197278913)
# ('OS-star', 0.5568367346938776)
# ('OS-all', [0.590985])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 159
# ('epoch#####555555555555##########################', 61)
# ('target from source1', [0.60267115])
# ('target from source2', [0.5843072])
# ('OS', 0.6771882086167801)
# ('OS-star', 0.6893367346938776)
# ('OS-all', [0.6527546])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 159
# ('epoch#####555555555555##########################', 62)
# ('target from source1', [0.59599334])
# ('target from source2', [0.5843072])
# ('OS', 0.6800566893424036)
# ('OS-star', 0.6869387755102041)
# ('OS-all', [0.66611016])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 148
# ('epoch#####555555555555##########################', 63)
# ('target from source1', [0.5676127])
# ('target from source2', [0.57929885])
# ('OS', 0.6591836734693878)
# ('OS-star', 0.6615816326530612)
# ('OS-all', [0.654424])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 146
# ('epoch#####555555555555##########################', 64)
# ('target from source1', [0.57429045])
# ('target from source2', [0.55592656])
# ('OS', 0.6622335600907029)
# ('OS-star', 0.6618877551020408)
# ('OS-all', [0.6627713])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 167
# ('epoch#####555555555555##########################', 65)
# ('target from source1', [0.5475793])
# ('target from source2', [0.5926544])
# ('OS', 0.6577891156462585)
# ('OS-star', 0.6543877551020408)
# ('OS-all', [0.66444075])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 165
# ('epoch#####555555555555##########################', 66)
# ('target from source1', [0.5141903])
# ('target from source2', [0.5993322])
# ('OS', 0.6620975056689342)
# ('OS-star', 0.661734693877551)
# ('OS-all', [0.6627713])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 184
# ('epoch#####555555555555##########################', 67)
# ('target from source1', [0.5926544])
# ('target from source2', [0.55592656])
# ('OS', 0.6493197278911566)
# ('OS-star', 0.6492346938775511)
# ('OS-all', [0.6494157])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 160
# ('epoch#####555555555555##########################', 68)
# ('target from source1', [0.54257095])
# ('target from source2', [0.49415693])
# ('OS', 0.6088095238095238)
# ('OS-star', 0.5867857142857142)
# ('OS-all', [0.6527546])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 175
# ('epoch#####555555555555##########################', 69)
# ('target from source1', [0.6076795])
# ('target from source2', [0.5676127])
# ('OS', 0.6582086167800454)
# ('OS-star', 0.661734693877551)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 163
# ('epoch#####555555555555##########################', 70)
# ('target from source1', [0.5843072])
# ('target from source2', [0.5692821])
# ('OS', 0.6503401360544218)
# ('OS-star', 0.6591326530612245)
# ('OS-all', [0.6327212])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 168
# ('epoch#####555555555555##########################', 71)
# ('target from source1', [0.5275459])
# ('target from source2', [0.5525876])
# ('OS', 0.6410317460317461)
# ('OS-star', 0.6317857142857143)
# ('OS-all', [0.6594324])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 148
# ('epoch#####555555555555##########################', 72)
# ('target from source1', [0.5692821])
# ('target from source2', [0.5926544])
# ('OS', 0.6492743764172335)
# ('OS-star', 0.6516836734693877)
# ('OS-all', [0.64440733])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 180
# ('epoch#####555555555555##########################', 73)
# ('target from source1', [0.54924875])
# ('target from source2', [0.5459098])
# ('OS', 0.6103854875283447)
# ('OS-star', 0.6016836734693878)
# ('OS-all', [0.62771285])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 167
# ('epoch#####555555555555##########################', 74)
# ('target from source1', [0.5442404])
# ('target from source2', [0.5475793])
# ('OS', 0.6507482993197279)
# ('OS-star', 0.6595918367346939)
# ('OS-all', [0.6327212])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 177
# ('epoch#####555555555555##########################', 75)
# ('target from source1', [0.5409015])
# ('target from source2', [0.54257095])
# ('OS', 0.6454761904761905)
# ('OS-star', 0.6442857142857144)
# ('OS-all', [0.64774626])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 163
# ('epoch#####555555555555##########################', 76)
# ('target from source1', [0.49749583])
# ('target from source2', [0.54924875])
# ('OS', 0.6683446712018141)
# ('OS-star', 0.6768877551020409)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 141
# ('epoch#####555555555555##########################', 77)
# ('target from source1', [0.55926543])
# ('target from source2', [0.58096826])
# ('OS', 0.6566326530612244)
# ('OS-star', 0.6593367346938775)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 173
# ('epoch#####555555555555##########################', 78)
# ('target from source1', [0.5141903])
# ('target from source2', [0.55592656])
# ('OS', 0.6561224489795918)
# ('OS-star', 0.6593877551020408)
# ('OS-all', [0.6494157])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 173
# ('epoch#####555555555555##########################', 79)
# ('target from source1', [0.5158598])
# ('target from source2', [0.5759599])
# ('OS', 0.6349659863945578)
# ('OS-star', 0.6318367346938776)
# ('OS-all', [0.64106846])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 161
# ('epoch#####555555555555##########################', 80)
# ('target from source1', [0.51252085])
# ('target from source2', [0.590985])
# ('OS', 0.6538095238095238)
# ('OS-star', 0.6592857142857143)
# ('OS-all', [0.6427379])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 145
# ('epoch#####555555555555##########################', 81)
# ('target from source1', [0.509182])
# ('target from source2', [0.5642738])
# ('OS', 0.627562358276644)
# ('OS-star', 0.6191326530612244)
# ('OS-all', [0.64440733])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 136
# ('epoch#####555555555555##########################', 82)
# ('target from source1', [0.49081802])
# ('target from source2', [0.5525876])
# ('OS', 0.631031746031746)
# ('OS-star', 0.6267857142857143)
# ('OS-all', [0.639399])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 172
# ('epoch#####555555555555##########################', 83)
# ('target from source1', [0.5175292])
# ('target from source2', [0.5642738])
# ('OS', 0.6549206349206349)
# ('OS-star', 0.6592857142857143)
# ('OS-all', [0.6460768])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 176
# ('epoch#####555555555555##########################', 84)
# ('target from source1', [0.5859766])
# ('target from source2', [0.57929885])
# ('OS', 0.6531632653061225)
# ('OS-star', 0.6541836734693878)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 176
# ('epoch#####555555555555##########################', 85)
# ('target from source1', [0.47579297])
# ('target from source2', [0.59599334])
# ('OS', 0.6293197278911564)
# ('OS-star', 0.624234693877551)
# ('OS-all', [0.639399])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 166
# ('epoch#####555555555555##########################', 86)
# ('target from source1', [0.5442404])
# ('target from source2', [0.5859766])
# ('OS', 0.6850566893424036)
# ('OS-star', 0.694438775510204)
# ('OS-all', [0.66611016])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 156
# ('epoch#####555555555555##########################', 87)
# ('target from source1', [0.49415693])
# ('target from source2', [0.51252085])
# ('OS', 0.6799659863945577)
# ('OS-star', 0.6843367346938776)
# ('OS-all', [0.67111856])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 138
# ('epoch#####555555555555##########################', 88)
# ('target from source1', [0.509182])
# ('target from source2', [0.54924875])
# ('OS', 0.6651020408163266)
# ('OS-star', 0.6669897959183674)
# ('OS-all', [0.6611018])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 144
# ('epoch#####555555555555##########################', 89)
# ('target from source1', [0.4891486])
# ('target from source2', [0.53589314])
# ('OS', 0.6465873015873016)
# ('OS-star', 0.6517857142857143)
# ('OS-all', [0.6360601])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 163
# ('epoch#####555555555555##########################', 90)
# ('target from source1', [0.49582636])
# ('target from source2', [0.52587646])
# ('OS', 0.6488095238095237)
# ('OS-star', 0.6492857142857142)
# ('OS-all', [0.64774626])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 164
# ('epoch#####555555555555##########################', 91)
# ('target from source1', [0.53422374])
# ('target from source2', [0.5509182])
# ('OS', 0.6482539682539682)
# ('OS-star', 0.6492857142857142)
# ('OS-all', [0.6460768])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 155
# ('epoch#####555555555555##########################', 92)
# ('target from source1', [0.5175292])
# ('target from source2', [0.5175292])
# ('OS', 0.6304308390022677)
# ('OS-star', 0.6267346938775511)
# ('OS-all', [0.6377295])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 164
# ('epoch#####555555555555##########################', 93)
# ('target from source1', [0.5008347])
# ('target from source2', [0.52921534])
# ('OS', 0.6565873015873015)
# ('OS-star', 0.6592857142857143)
# ('OS-all', [0.65108514])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 138
# ('epoch#####555555555555##########################', 94)
# ('target from source1', [0.5709516])
# ('target from source2', [0.5208681])
# ('OS', 0.6426530612244898)
# ('OS-star', 0.634234693877551)
# ('OS-all', [0.6594324])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 161
# ('epoch#####555555555555##########################', 95)
# ('target from source1', [0.49749583])
# ('target from source2', [0.53589314])
# ('OS', 0.6538095238095238)
# ('OS-star', 0.6592857142857143)
# ('OS-all', [0.6427379])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 155
# ('epoch#####555555555555##########################', 96)
# ('target from source1', [0.50584304])
# ('target from source2', [0.5375626])
# ('OS', 0.6516780045351473)
# ('OS-star', 0.6493877551020408)
# ('OS-all', [0.6560935])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 161
# ('epoch#####555555555555##########################', 97)
# ('target from source1', [0.5075125])
# ('target from source2', [0.55592656])
# ('OS', 0.6638548752834468)
# ('OS-star', 0.6693367346938776)
# ('OS-all', [0.6527546])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 168
# ('epoch#####555555555555##########################', 98)
# ('target from source1', [0.49582636])
# ('target from source2', [0.55926543])
# ('OS', 0.6332086167800454)
# ('OS-star', 0.629234693877551)
# ('OS-all', [0.64106846])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# 156
# ('epoch#####555555555555##########################', 99)
# ('target from source1', [0.55926543])
# ('target from source2', [0.5542571])
# ('OS', 0.6376984126984127)
# ('OS-star', 0.6367857142857143)
# ('OS-all', [0.639399])
# print highest source1: 0.644407, epoch13.000000
# print highest source2: 0.609349, epoch13.000000
# print highest OS: 0.715658, epoch13.000000
# print highest OS-star: 0.749490, epoch13.000000
# print highest ALL: 0.647746, epoch13.000000
# Training Complete
